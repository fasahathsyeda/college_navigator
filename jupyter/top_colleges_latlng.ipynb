# %%
import pandas as pd
from opencage.geocoder import OpenCageGeocode

# %%
api_key="a303a88d62944cd4aaa04cc91f8e3518"

# %%
geocoder = OpenCageGeocode(api_key)

# %%
col_data=pd.read_csv("../Data/ForbesAmericasTopColleges2019.csv")
col_data.head()
# Out:
#    Rank                                   Name       City State  \
# 0     1                     Harvard University  Cambridge    MA
# 1     2                    Stanford University   Stanford    CA
# 2     3                        Yale University  New Haven    CT
# 3     4  Massachusetts Institute of Technology  Cambridge    MA
# 4     5                   Princeton University  Princeton    NJ
#
#   Public/Private  Undergraduate Population  Student Population  Net Price  \
# 0        Private                     13844               31120    14327.0
# 1        Private                      8402               17534    13261.0
# 2        Private                      6483               12974    18627.0
# 3        Private                      4680               11466    20771.0
# 4        Private                      5659                8273     9327.0
#
#    Average Grant Aid  Total Annual Cost  Alumni Salary  Acceptance Rate  \
# ...

# %%
list_lat = []   # create empty lists

list_long = []



for index, row in col_data.iterrows(): # iterate over rows in dataframe



    City = row['City']
    State = row['State'] 
    Country = 'USA'
    query = str(City)+','+str(State)+','+str(Country)

    results = geocoder.geocode(query)   
    lat = results[0]['geometry']['lat']
    long = results[0]['geometry']['lng']

    list_lat.append(lat)
    list_long.append(long)


# create new columns from lists    

col_data['lat'] = list_lat   

col_data['lon'] = list_long

# %%
col_data.head()
# Out:
#    Rank                                   Name       City State  \
# 0     1                     Harvard University  Cambridge    MA
# 1     2                    Stanford University   Stanford    CA
# 2     3                        Yale University  New Haven    CT
# 3     4  Massachusetts Institute of Technology  Cambridge    MA
# 4     5                   Princeton University  Princeton    NJ
#
#   Public/Private  Undergraduate Population  Student Population  Net Price  \
# 0        Private                     13844               31120    14327.0
# 1        Private                      8402               17534    13261.0
# 2        Private                      6483               12974    18627.0
# 3        Private                      4680               11466    20771.0
# 4        Private                      5659                8273     9327.0
#
#    Average Grant Aid  Total Annual Cost  Alumni Salary  Acceptance Rate  \
# ...

# %%
col_data=col_data.fillna("")

# %%
col_data
# Out:
#      Rank                                   Name         City State  \
# 0       1                     Harvard University    Cambridge    MA
# 1       2                    Stanford University     Stanford    CA
# 2       3                        Yale University    New Haven    CT
# 3       4  Massachusetts Institute of Technology    Cambridge    MA
# 4       5                   Princeton University    Princeton    NJ
# ..    ...                                    ...          ...   ...
# 645   646            New Mexico State University   Las Cruces    NM
# 646   647               Indiana State University  Terre Haute    IN
# 647   648              Emory &amp; Henry College        Emory    VA
# 648   649                          Wells College       Aurora    NY
# 649   650                        Catawba College    Salisbury    NC
#
#     Public/Private  Undergraduate Population  Student Population Net Price  \
# ...

# %%
col_data.to_csv("../Data/top_colleges_latlng.csv")

# %%
col_data=pd.read_csv("../Data/top_colleges_latlng.csv")

# %%
col_data
# Out:
#      Unnamed: 0  Rank                                   Name         City  \
# 0             0     1                     Harvard University    Cambridge
# 1             1     2                    Stanford University     Stanford
# 2             2     3                        Yale University    New Haven
# 3             3     4  Massachusetts Institute of Technology    Cambridge
# 4             4     5                   Princeton University    Princeton
# ..          ...   ...                                    ...          ...
# 645         645   646            New Mexico State University   Las Cruces
# 646         646   647               Indiana State University  Terre Haute
# 647         647   648              Emory &amp; Henry College        Emory
# 648         648   649                          Wells College       Aurora
# 649         649   650                        Catawba College    Salisbury
#
#     State Public/Private  Undergraduate Population  Student Population  \
# ...

# %%
del col_data['Unnamed: 0']

# %%
col_data.isnull().sum()
# Out:
# Rank                         0
# Name                         0
# City                         3
# State                        0
# Public/Private               0
# Undergraduate Population     0
# Student Population           0
# Net Price                    2
# Average Grant Aid            4
# Total Annual Cost            0
# Alumni Salary               15
# Acceptance Rate              2
# SAT Lower                   99
# SAT Upper                   99
# ACT Lower                   97
# ACT Upper                   97
# Website                      5
# lat                          0
# lon                          0
# dtype: int64

# %%
col_data
# Out:
#      Rank                                   Name         City State  \
# 0       1                     Harvard University    Cambridge    MA
# 1       2                    Stanford University     Stanford    CA
# 2       3                        Yale University    New Haven    CT
# 3       4  Massachusetts Institute of Technology    Cambridge    MA
# 4       5                   Princeton University    Princeton    NJ
# ..    ...                                    ...          ...   ...
# 645   646            New Mexico State University   Las Cruces    NM
# 646   647               Indiana State University  Terre Haute    IN
# 647   648              Emory &amp; Henry College        Emory    VA
# 648   649                          Wells College       Aurora    NY
# 649   650                        Catawba College    Salisbury    NC
#
#     Public/Private  Undergraduate Population  Student Population  Net Price  \
# ...

# %%
col_data.rename(columns={"State":"Code"},inplace=True)

# %%
col_data.head()
# Out:
#    Rank                                   Name       City Code Public/Private  \
# 0     1                     Harvard University  Cambridge   MA        Private
# 1     2                    Stanford University   Stanford   CA        Private
# 2     3                        Yale University  New Haven   CT        Private
# 3     4  Massachusetts Institute of Technology  Cambridge   MA        Private
# 4     5                   Princeton University  Princeton   NJ        Private
#
#    Undergraduate Population  Student Population  Net Price  Average Grant Aid  \
# 0                     13844               31120    14327.0            49870.0
# 1                      8402               17534    13261.0            50134.0
# 2                      6483               12974    18627.0            50897.0
# 3                      4680               11466    20771.0            43248.0
# 4                      5659                8273     9327.0            48088.0
#
# ...

# %%
abbr=pd.read_csv("../Data/state_abbr.csv")
abbr
# Out:
#                    State  Abbrev Code
# 0                Alabama    Ala.   AL
# 1                 Alaska  Alaska   AK
# 2                Arizona   Ariz.   AZ
# 3               Arkansas    Ark.   AR
# 4             California  Calif.   CA
# 5               Colorado   Colo.   CO
# 6            Connecticut   Conn.   CT
# 7               Delaware    Del.   DE
# 8   District of Columbia    D.C.   DC
# 9                Florida    Fla.   FL
# 10               Georgia     Ga.   GA
# 11                Hawaii  Hawaii   HI
# 12                 Idaho   Idaho   ID
# 13              Illinois    Ill.   IL
# 14               Indiana    Ind.   IN
# 15                  Iowa    Iowa   IA
# 16                Kansas   Kans.   KS
# 17              Kentucky     Ky.   KY
# 18             Louisiana     La.   LA
# 19                 Maine   Maine   ME
# 20              Maryland     Md.   MD
# 21         Massachusetts   Mass.   MA
# 22              Michigan   Mich.   MI
# 23             Minnesota   Minn.   MN
# ...

# %%
del abbr['Abbrev']

# %%
abbr.head()
# Out:
#         State Code
# 0     Alabama   AL
# 1      Alaska   AK
# 2     Arizona   AZ
# 3    Arkansas   AR
# 4  California   CA

# %%
col_data.count()
# Out:
# Rank                        650
# Name                        650
# City                        647
# Code                        650
# Public/Private              650
# Undergraduate Population    650
# Student Population          650
# Net Price                   648
# Average Grant Aid           646
# Total Annual Cost           650
# Alumni Salary               635
# Acceptance Rate             648
# SAT Lower                   551
# SAT Upper                   551
# ACT Lower                   553
# ACT Upper                   553
# Website                     645
# lat                         650
# lon                         650
# dtype: int64

# %%
col_data=pd.merge(col_data,abbr, how='left', on=['Code'])

# %%
col_data.head()
# Out:
#    Rank                                   Name       City Code Public/Private  \
# 0     1                     Harvard University  Cambridge   MA        Private
# 1     2                    Stanford University   Stanford   CA        Private
# 2     3                        Yale University  New Haven   CT        Private
# 3     4  Massachusetts Institute of Technology  Cambridge   MA        Private
# 4     5                   Princeton University  Princeton   NJ        Private
#
#    Undergraduate Population  Student Population  Net Price  Average Grant Aid  \
# 0                     13844               31120    14327.0            49870.0
# 1                      8402               17534    13261.0            50134.0
# 2                      6483               12974    18627.0            50897.0
# 3                      4680               11466    20771.0            43248.0
# 4                      5659                8273     9327.0            48088.0
#
# ...

# %%
col_data.count()
# Out:
# Rank                        650
# Name                        650
# City                        647
# Code                        650
# Public/Private              650
# Undergraduate Population    650
# Student Population          650
# Net Price                   648
# Average Grant Aid           646
# Total Annual Cost           650
# Alumni Salary               635
# Acceptance Rate             648
# SAT Lower                   551
# SAT Upper                   551
# ACT Lower                   553
# ACT Upper                   553
# Website                     645
# lat                         650
# lon                         650
# State                       650
# dtype: int64

# %%
col_data.isnull().sum()
# Out:
# Rank                         0
# Name                         0
# City                         3
# Code                         0
# Public/Private               0
# Undergraduate Population     0
# Student Population           0
# Net Price                    2
# Average Grant Aid            4
# Total Annual Cost            0
# Alumni Salary               15
# Acceptance Rate              2
# SAT Lower                   99
# SAT Upper                   99
# ACT Lower                   97
# ACT Upper                   97
# Website                      5
# lat                          0
# lon                          0
# State                        0
# dtype: int64

# %%
col_data=col_data.fillna("")

# %%
col_data.isnull().sum()
# Out:
# Rank                        0
# Name                        0
# City                        0
# Code                        0
# Public/Private              0
# Undergraduate Population    0
# Student Population          0
# Net Price                   0
# Average Grant Aid           0
# Total Annual Cost           0
# Alumni Salary               0
# Acceptance Rate             0
# SAT Lower                   0
# SAT Upper                   0
# ACT Lower                   0
# ACT Upper                   0
# Website                     0
# lat                         0
# lon                         0
# State                       0
# dtype: int64

# %%
col_data=col_data.fillna("")

# %%
col_data.count()
# Out:
# Rank                        650
# Name                        650
# City                        650
# Code                        650
# Public/Private              650
# Undergraduate Population    650
# Student Population          650
# Net Price                   650
# Average Grant Aid           650
# Total Annual Cost           650
# Alumni Salary               650
# Acceptance Rate             650
# SAT Lower                   650
# SAT Upper                   650
# ACT Lower                   650
# ACT Upper                   650
# Website                     650
# lat                         650
# lon                         650
# State                       650
# dtype: int64

# %%
col_data.columns
# Out:
# Index(['Rank', 'Name', 'City', 'Code', 'Public/Private',
#        'Undergraduate Population', 'Student Population', 'Net Price',
#        'Average Grant Aid', 'Total Annual Cost', 'Alumni Salary',
#        'Acceptance Rate', 'SAT Lower', 'SAT Upper', 'ACT Lower', 'ACT Upper',
#        'Website', 'lat', 'lon', 'State'],
#       dtype='object')

# %%
col_data.dtypes
# Out:
# Rank                          int64
# Name                         object
# City                         object
# Code                         object
# Public/Private               object
# Undergraduate Population      int64
# Student Population            int64
# Net Price                    object
# Average Grant Aid            object
# Total Annual Cost             int64
# Alumni Salary                object
# Acceptance Rate              object
# SAT Lower                    object
# SAT Upper                    object
# ACT Lower                    object
# ACT Upper                    object
# Website                      object
# lat                         float64
# lon                         float64
# State                        object
# dtype: object

# %%
col_data.head()
# Out:
#    Rank                                   Name       City Code Public/Private  \
# 0     1                     Harvard University  Cambridge   MA        Private
# 1     2                    Stanford University   Stanford   CA        Private
# 2     3                        Yale University  New Haven   CT        Private
# 3     4  Massachusetts Institute of Technology  Cambridge   MA        Private
# 4     5                   Princeton University  Princeton   NJ        Private
#
#    Undergraduate Population  Student Population Net Price Average Grant Aid  \
# 0                     13844               31120     14327             49870
# 1                      8402               17534     13261             50134
# 2                      6483               12974     18627             50897
# 3                      4680               11466     20771             43248
# 4                      5659                8273      9327             48088
#
# ...

# %%
col_data.to_csv("../Data/plotting1.csv",index=False,na_rep="")

# %%
import json
json_data=[]
temp_data={}
data=[]
dict_json={}
for index,row in col_data.iterrows():
    geometry={
        "x":row["lat"],
           "y":row["lon"]
    }
    properties={
        "Rank":row["Rank"], 
        "Name":row["Name"], 
        "City":row["City"], 
        "State":row["State"],
        "Code":row["Code"],
        "Public/Private":row["Public/Private"],
        "Undergraduate Population":row["Undergraduate Population"],
        "Student Population":row["Student Population"],
        "Net Price":row["Net Price"],
        "Average Grant Aid":row["Average Grant Aid"], 
        "Total Annual Cost":row["Total Annual Cost"], 
        "Alumni Salary":row["Alumni Salary"],
        "Acceptance Rate":row["Acceptance Rate"], 
        "SAT Lower":row["SAT Lower"], 
        "SAT Upper":row["SAT Upper"], 
        "ACT Lower":row["ACT Lower"], 
        "ACT Upper":row["ACT Upper"],
        "Website":row["Website"],
        "lat":row["lat"], 
        "lon":row["lon"]

    }
    json_data.append({
        "type":"Features",
        "geometry":geometry,
        "properties":properties
    })

# %%
final_json={
        "features":json_data
    }

# %%
with open("../Data/top_college_final_latlon_json2.json", 'w') as outfile:
    outfile.write(json.dumps(json_data))

# %%
col_data.to_json("../Data/plot.json")

# %%
df2=pd.read_csv("../Data/plotting1.csv",keep_default_na=False)
df2
# Out:
#      Rank                                   Name         City Code  \
# 0       1                     Harvard University    Cambridge   MA
# 1       2                    Stanford University     Stanford   CA
# 2       3                        Yale University    New Haven   CT
# 3       4  Massachusetts Institute of Technology    Cambridge   MA
# 4       5                   Princeton University    Princeton   NJ
# ..    ...                                    ...          ...  ...
# 645   646            New Mexico State University   Las Cruces   NM
# 646   647               Indiana State University  Terre Haute   IN
# 647   648              Emory &amp; Henry College        Emory   VA
# 648   649                          Wells College       Aurora   NY
# 649   650                        Catawba College    Salisbury   NC
#
#     Public/Private  Undergraduate Population  Student Population Net Price  \
# 0          Private                     13844               31120   14327.0
# ...

# %%
df2.isnull().sum()
# Out:
# Rank                        0
# Name                        0
# City                        0
# Code                        0
# Public/Private              0
# Undergraduate Population    0
# Student Population          0
# Net Price                   0
# Average Grant Aid           0
# Total Annual Cost           0
# Alumni Salary               0
# Acceptance Rate             0
# SAT Lower                   0
# SAT Upper                   0
# ACT Lower                   0
# ACT Upper                   0
# Website                     0
# lat                         0
# lon                         0
# State                       0
# dtype: int64

# %%
import json
df3=pd.read_json("../Data/plot.json")
df3
# Out:
#      Rank                                   Name         City Code  \
# 0       1                     Harvard University    Cambridge   MA
# 1       2                    Stanford University     Stanford   CA
# 2       3                        Yale University    New Haven   CT
# 3       4  Massachusetts Institute of Technology    Cambridge   MA
# 4       5                   Princeton University    Princeton   NJ
# ..    ...                                    ...          ...  ...
# 645   646            New Mexico State University   Las Cruces   NM
# 646   647               Indiana State University  Terre Haute   IN
# 647   648              Emory &amp; Henry College        Emory   VA
# 648   649                          Wells College       Aurora   NY
# 649   650                        Catawba College    Salisbury   NC
#
#     Public/Private  Undergraduate Population  Student Population Net Price  \
# 0          Private                     13844               31120     14327
# ...

# %%
json_data=[]
temp_data={}
data=[]
dict_json={}
for index,row in df3.iterrows():
#     geometry={
#         "x":row["lat"],
#            "y":row["lon"]
#     }
    properties={
        "Rank":row["Rank"], 
        "Name":row["Name"], 
        "City":row["City"], 
        "State":row["State"],
        "Code":row["Code"],
        "Public/Private":row["Public/Private"],
        "Undergraduate Population":row["Undergraduate Population"],
        "Student Population":row["Student Population"],
        "Net Price":row["Net Price"],
        "Average Grant Aid":row["Average Grant Aid"], 
        "Total Annual Cost":row["Total Annual Cost"], 
        "Alumni Salary":row["Alumni Salary"],
        "Acceptance Rate":row["Acceptance Rate"], 
        "SAT Lower":row["SAT Lower"], 
        "SAT Upper":row["SAT Upper"], 
        "ACT Lower":row["ACT Lower"], 
        "ACT Upper":row["ACT Upper"],
        "Website":row["Website"],
        "lat":row["lat"], 
        "lon":row["lon"]

    }
    json_data.append({
#         "type":"Features",
#         "geometry":geometry,
        "properties":properties
    })

# %%
final_json={
        "features":json_data
    }

# %%
with open("../Data/plot_newjson.json", 'w') as outfile:
    outfile.write(json.dumps(json_data))

# %%
# Out:
# 'ab'
